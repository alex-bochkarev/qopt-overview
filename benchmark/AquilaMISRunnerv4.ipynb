# %%
from braket.tracking import Tracker
from braket.aws import AwsDevice
import json
import numpy as np
from braket.ahs.atom_arrangement import AtomArrangement
#from ahs_utils import show_register
from braket.ahs.driving_field import DrivingField
#from ahs_utils import show_global_drive
from braket.ahs.analog_hamiltonian_simulation import AnalogHamiltonianSimulation
from braket.devices import LocalSimulator
#from ahs_utils import show_final_avg_density
import time
import os
import datetime

version = '1.1'
    
# Use Braket SDK Cost Tracking to estimate the cost to run this example
tracker = Tracker().start()

# Get device capabilities
qpu = AwsDevice("arn:aws:braket:us-east-1::device/qpu/quera/Aquila")
field_of_view_width = qpu.properties.paradigm.lattice.area.width
field_of_view_height = qpu.properties.paradigm.lattice.area.height
n_site_max = qpu.properties.paradigm.lattice.geometry.numberSitesMax
C6 = float(qpu.properties.paradigm.rydberg.c6Coefficient)

# define postprocessing
def get_counters_from_result(result):
    post_sequences = [list(measurement.post_sequence) for measurement in result.measurements]
    post_sequences = ["".join(['r' if site==0 else 'g' for site in post_sequence]) for post_sequence in post_sequences]
    counters = {}
    for post_sequence in post_sequences:
        if post_sequence in counters:
            counters[post_sequence] += 1
        else:
            counters[post_sequence] = 1
    return counters

def run_example(filename, Delta_final= 20e6, simulator_max_qubits=10, qpu_max_qubits=256, shots=100, nsteps=1000, plot=False):
    # start
    print('process', filename, datetime.datetime.now())
    timestamp_start=datetime.datetime.now().timestamp()

    # Find blockade radius
    blockade_radius = (C6/(Delta_final))**(1/6) # sqrt(delta^2 + omega^2)
    print(f'Delta_final     = {Delta_final}')
    print(f'C6              = {C6}')
    print(f'blockade_radius = {blockade_radius}')
    
    # load file
    with open(filename, 'r') as fh:
        instance_data = json.load(fh)
    
    # setup coordinates
    x_min = np.min([x for x,y in instance_data['description']['points'].values()])
    y_min = np.min([y for x,y in instance_data['description']['points'].values()])
    R = instance_data['description']['R']
    factor = (blockade_radius / R)
    data = np.zeros((len(instance_data['nodes']),2))
    for i,(x,y) in instance_data['description']['points'].items():
        data[int(i)-1,0] = (x-x_min)*factor
        data[int(i)-1,1] = (y-y_min)*factor
    print(f'data dimension: {data.shape}, factor: {factor}')

    # setup register
    register = AtomArrangement()
    for x, y in data:
        pos = (x, y)
        register.add(pos)

    # setup controls
    time_points = [0, 2.5e-7, 2.75e-6, 3e-6] # s
    amplitude_min = 0
    amplitude_max = 1.57e7  # rad / s
    detuning_min = -Delta_final  # rad / s
    detuning_max = Delta_final   # rad / s
    amplitude_values = [amplitude_min, amplitude_max, amplitude_max, amplitude_min]
    detuning_values = [detuning_min, detuning_min, detuning_max, detuning_max]
    phase_values = [0, 0, 0, 0]
    drive = DrivingField.from_lists(time_points, amplitude_values, detuning_values, phase_values)

    # build simulation
    ahs_program = AnalogHamiltonianSimulation(
        register=register, 
        hamiltonian=drive
    )
    ahs_program = ahs_program.discretize(qpu)
    
    # set engines
    num_qubits = len(instance_data['nodes'])
    print(f'num_qubits: {num_qubits}')
    run_simulator = simulator_max_qubits >= num_qubits
    run_qpu = qpu_max_qubits >= num_qubits
    
    # simulator
    try:
        if not run_simulator:
            raise ValueError('simulator turned off')
        print('run simulator', datetime.datetime.now())
        sim_timestamp = datetime.datetime.now().timestamp()
        sim = LocalSimulator("braket_ahs")
        start_time = time.time()
        sim_result = sim.run(ahs_program, shots=shots, nsteps=nsteps).result()
        end_time = time.time()
        sim_density = sim_result.get_avg_density()
        sim_counts = get_counters_from_result(sim_result)
        sim_dt = end_time-start_time
    except Exception as e:
        print('simulator', e)
        sim_result = None
        sim_timestamp = None
        sim_density = None
        sim_counts = None
        sim_dt = None
        
    # hardware
    try:
        if not run_qpu:
            raise ValueError('qpu turned off')
        print('run qpu', datetime.datetime.now())
        qpu_timestamp = datetime.datetime.now().timestamp()
        start_time = time.time()
        qpu_result = qpu.run(ahs_program, shots=100).result()
        end_time = time.time()
        qpu_density = qpu_result.get_avg_density()
        qpu_counts = get_counters_from_result(qpu_result)
        qpu_dt = end_time-start_time
    except Exception as e:
        print('qpu', e)
        qpu_result = None
        qpu_timestamp = None
        qpu_density = None
        qpu_counts = None
        qpu_dt = None
        
    # end
    timestamp_end=datetime.datetime.now().timestamp()        
        
    # save
    instance_name = os.path.split(os.path.splitext(filename)[0])[1]
    result_filename = f'results/result_{instance_name}_{timestamp_start}.json'
    result_data = dict(problem=dict(instance_name=instance_name, instance_data=data.tolist()),
                       meta=dict(timestamp_start=timestamp_start, timestamp_end=timestamp_end, version=version),
                       sim_result=dict(sim_density=sim_density.tolist() if sim_density is not None else None, sim_counts=sim_counts, sim_dt=sim_dt, sim_timestamp=sim_timestamp),
                       qpu_result=dict(qpu_density=qpu_density.tolist() if qpu_density is not None else None, qpu_counts=qpu_counts, qpu_dt=qpu_dt, qpu_timestamp=qpu_timestamp),
                       settings=dict(time_points = time_points, amplitude_values = amplitude_values, detuning_values = detuning_values,
                       phase_values = phase_values,
                       blockade_radius=float(blockade_radius), n_site_max=int(n_site_max), C6=float(C6), x_min=int(x_min), y_min=int(y_min), R=float(R), factor=float(factor)))
    with open(result_filename, 'w') as fh:
        json.dump(result_data, fh)
    print('saved to', result_filename)

    # show
    print('finished', datetime.datetime.now())
    if plot:
        display(show_register(register))
        display(show_global_drive(drive))
        if sim_result is not None:
            print('simulation')
            display(show_final_avg_density(sim_result))
        if qpu_result is not None:
            print('qpu')
            display(show_final_avg_density(qpu_result))
    
    return result_data

# %%
###

# %%
import glob

for filename in glob.glob('instances/*.json'):
    result_data = run_example(filename)
    #break
# Out:
# process instances/UDMIS081EXT_N30_W1.0_R0.3.orig.json 2023-11-15 22:24:27.943514
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (30, 2), factor: 4.348336584291281e-06
# num_qubits: 30
# simulator simulator turned off
# run qpu 2023-11-15 22:24:27.948491
# saved to results/result_UDMIS081EXT_N30_W1.0_R0.3.orig_1700087067.943621.json
# finished 2023-11-15 22:25:28.134034
# process instances/UDMIS028EXT_N90_W1.0_R0.1.orig.json 2023-11-15 22:25:28.134741
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (90, 2), factor: 6.435538144751096e-06
# num_qubits: 90
# simulator simulator turned off
# run qpu 2023-11-15 22:25:28.137938
# saved to results/result_UDMIS028EXT_N90_W1.0_R0.1.orig_1700087128.134779.json
# finished 2023-11-15 22:26:29.331389
# process instances/UDMIS013EXT_N40_W1.0_R0.2.orig.json 2023-11-15 22:26:29.332119
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (40, 2), factor: 6.435538144751096e-06
# num_qubits: 40
# simulator simulator turned off
# run qpu 2023-11-15 22:26:29.336432
# saved to results/result_UDMIS013EXT_N40_W1.0_R0.2.orig_1700087189.332642.json
# finished 2023-11-15 22:27:28.148520
# process instances/UDMIS082EXT_N36_W1.0_R0.3.orig.json 2023-11-15 22:27:28.148718
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (36, 2), factor: 4.348336584291281e-06
# num_qubits: 36
# simulator simulator turned off
# run qpu 2023-11-15 22:27:28.152541
# saved to results/result_UDMIS082EXT_N36_W1.0_R0.3.orig_1700087248.148733.json
# finished 2023-11-15 22:28:24.801432
# process instances/UDMIS089EXT_N49_W1.0_R0.2.orig.json 2023-11-15 22:28:24.803312
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (49, 2), factor: 4.348336584291281e-06
# num_qubits: 49
# simulator simulator turned off
# run qpu 2023-11-15 22:28:24.806518
# saved to results/result_UDMIS089EXT_N49_W1.0_R0.2.orig_1700087304.803355.json
# finished 2023-11-15 22:29:22.175154
# process instances/UDMIS106EXT_N120_W1.0_R0.2.orig.json 2023-11-15 22:29:22.175367
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (120, 2), factor: 4.348336584291281e-06
# num_qubits: 120
# simulator simulator turned off
# run qpu 2023-11-15 22:29:22.178295
# saved to results/result_UDMIS106EXT_N120_W1.0_R0.2.orig_1700087362.175383.json
# finished 2023-11-15 22:30:19.637916
# process instances/UDMIS063EXT_N80_W1.0_R0.1.orig.json 2023-11-15 22:30:19.638359
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (80, 2), factor: 5.665086395027374e-06
# num_qubits: 80
# simulator simulator turned off
# run qpu 2023-11-15 22:30:19.640771
# saved to results/result_UDMIS063EXT_N80_W1.0_R0.1.orig_1700087419.638391.json
# finished 2023-11-15 22:31:16.483881
# process instances/UDMIS039EXT_N15_W1.0_R0.3.orig.json 2023-11-15 22:31:16.484138
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (15, 2), factor: 5.665086395027374e-06
# num_qubits: 15
# simulator simulator turned off
# run qpu 2023-11-15 22:31:16.485195
# saved to results/result_UDMIS039EXT_N15_W1.0_R0.3.orig_1700087476.484156.json
# finished 2023-11-15 22:32:13.842519
# process instances/UDMIS021EXT_N60_W1.0_R0.1.orig.json 2023-11-15 22:32:13.843488
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (60, 2), factor: 6.435538144751096e-06
# num_qubits: 60
# simulator simulator turned off
# run qpu 2023-11-15 22:32:13.846562
# saved to results/result_UDMIS021EXT_N60_W1.0_R0.1.orig_1700087533.843523.json
# finished 2023-11-15 22:33:12.607542
# process instances/UDMIS043EXT_N30_W1.0_R0.2.orig.json 2023-11-15 22:33:12.607789
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (30, 2), factor: 5.665086395027374e-06
# num_qubits: 30
# simulator simulator turned off
# run qpu 2023-11-15 22:33:12.609320
# saved to results/result_UDMIS043EXT_N30_W1.0_R0.2.orig_1700087592.607805.json
# finished 2023-11-15 22:34:09.878506
# process instances/UDMIS009EXT_N30_W1.0_R0.2.orig.json 2023-11-15 22:34:09.880398
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (30, 2), factor: 6.435538144751096e-06
# num_qubits: 30
# simulator simulator turned off
# run qpu 2023-11-15 22:34:09.881796
# saved to results/result_UDMIS009EXT_N30_W1.0_R0.2.orig_1700087649.880423.json
# finished 2023-11-15 22:35:07.161466
# process instances/UDMIS047EXT_N36_W1.0_R0.2.orig.json 2023-11-15 22:35:07.161704
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (36, 2), factor: 5.665086395027374e-06
# num_qubits: 36
# simulator simulator turned off
# run qpu 2023-11-15 22:35:07.163009
# saved to results/result_UDMIS047EXT_N36_W1.0_R0.2.orig_1700087707.161719.json
# finished 2023-11-15 22:36:04.718419
# process instances/UDMIS101EXT_N90_W1.0_R0.2.orig.json 2023-11-15 22:36:04.718687
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (90, 2), factor: 4.348336584291281e-06
# num_qubits: 90
# simulator simulator turned off
# run qpu 2023-11-15 22:36:04.721159
# saved to results/result_UDMIS101EXT_N90_W1.0_R0.2.orig_1700087764.718704.json
# finished 2023-11-15 22:37:02.532203
# process instances/UDMIS094EXT_N70_W1.0_R0.2.orig.json 2023-11-15 22:37:02.532560
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (70, 2), factor: 4.348336584291281e-06
# num_qubits: 70
# simulator simulator turned off
# run qpu 2023-11-15 22:37:02.535462
# saved to results/result_UDMIS094EXT_N70_W1.0_R0.2.orig_1700087822.532585.json
# finished 2023-11-15 22:38:00.240262
# process instances/UDMIS002EXT_N15_W1.0_R0.2.orig.json 2023-11-15 22:38:00.240791
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (15, 2), factor: 6.435538144751096e-06
# num_qubits: 15
# simulator simulator turned off
# run qpu 2023-11-15 22:38:00.241951
# saved to results/result_UDMIS002EXT_N15_W1.0_R0.2.orig_1700087880.24082.json
# finished 2023-11-15 22:38:58.587971
# process instances/UDMIS086EXT_N40_W1.0_R0.2.orig.json 2023-11-15 22:38:58.588582
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (40, 2), factor: 4.348336584291281e-06
# num_qubits: 40
# simulator simulator turned off
# run qpu 2023-11-15 22:38:58.593060
# saved to results/result_UDMIS086EXT_N40_W1.0_R0.2.orig_1700087938.588788.json
# finished 2023-11-15 22:39:57.502515
# process instances/UDMIS073EXT_N15_W1.0_R0.4.orig.json 2023-11-15 22:39:57.502709
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (15, 2), factor: 4.348336584291281e-06
# num_qubits: 15
# simulator simulator turned off
# run qpu 2023-11-15 22:39:57.503846
# saved to results/result_UDMIS073EXT_N15_W1.0_R0.4.orig_1700087997.502726.json
# finished 2023-11-15 22:40:55.043099
# process instances/UDMIS026EXT_N80_W1.0_R0.1.orig.json 2023-11-15 22:40:55.043707
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (80, 2), factor: 6.435538144751096e-06
# num_qubits: 80
# simulator simulator turned off
# run qpu 2023-11-15 22:40:55.046405
# saved to results/result_UDMIS026EXT_N80_W1.0_R0.1.orig_1700088055.04374.json
# finished 2023-11-15 22:41:52.823744
# process instances/UDMIS038EXT_N15_W1.0_R0.3.orig.json 2023-11-15 22:41:52.824004
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (15, 2), factor: 5.665086395027374e-06
# num_qubits: 15
# simulator simulator turned off
# run qpu 2023-11-15 22:41:52.825479
# saved to results/result_UDMIS038EXT_N15_W1.0_R0.3.orig_1700088112.824027.json
# finished 2023-11-15 22:42:50.272695
# process instances/UDMIS008EXT_N30_W1.0_R0.2.orig.json 2023-11-15 22:42:50.272874
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (30, 2), factor: 6.435538144751096e-06
# num_qubits: 30
# simulator simulator turned off
# run qpu 2023-11-15 22:42:50.274545
# saved to results/result_UDMIS008EXT_N30_W1.0_R0.2.orig_1700088170.272889.json
# finished 2023-11-15 22:43:46.890053
# process instances/UDMIS069EXT_N100_W1.0_R0.1.orig.json 2023-11-15 22:43:46.890301
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (100, 2), factor: 5.665086395027374e-06
# num_qubits: 100
# simulator simulator turned off
# run qpu 2023-11-15 22:43:46.896668
# saved to results/result_UDMIS069EXT_N100_W1.0_R0.1.orig_1700088226.89032.json
# finished 2023-11-15 22:44:44.891163
# process instances/UDMIS030EXT_N90_W1.0_R0.1.orig.json 2023-11-15 22:44:44.891692
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (90, 2), factor: 6.435538144751096e-06
# num_qubits: 90
# simulator simulator turned off
# run qpu 2023-11-15 22:44:44.896349
# saved to results/result_UDMIS030EXT_N90_W1.0_R0.1.orig_1700088284.891729.json
# finished 2023-11-15 22:45:44.261264
# process instances/UDMIS049EXT_N40_W1.0_R0.2.orig.json 2023-11-15 22:45:44.261696
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (40, 2), factor: 5.665086395027374e-06
# num_qubits: 40
# simulator simulator turned off
# run qpu 2023-11-15 22:45:44.265084
# saved to results/result_UDMIS049EXT_N40_W1.0_R0.2.orig_1700088344.261726.json
# finished 2023-11-15 22:46:43.117245
# process instances/UDMIS084EXT_N36_W1.0_R0.3.orig.json 2023-11-15 22:46:43.117537
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (36, 2), factor: 4.348336584291281e-06
# num_qubits: 36
# simulator simulator turned off
# run qpu 2023-11-15 22:46:43.118932
# saved to results/result_UDMIS084EXT_N36_W1.0_R0.3.orig_1700088403.117559.json
# finished 2023-11-15 22:47:40.606802
# process instances/UDMIS058EXT_N70_W1.0_R0.1.orig.json 2023-11-15 22:47:40.606995
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (70, 2), factor: 5.665086395027374e-06
# num_qubits: 70
# simulator simulator turned off
# run qpu 2023-11-15 22:47:40.609398
# saved to results/result_UDMIS058EXT_N70_W1.0_R0.1.orig_1700088460.607011.json
# finished 2023-11-15 22:48:37.526707
# process instances/UDMIS012EXT_N36_W1.0_R0.2.orig.json 2023-11-15 22:48:37.527070
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (36, 2), factor: 6.435538144751096e-06
# num_qubits: 36
# simulator simulator turned off
# run qpu 2023-11-15 22:48:37.528847
# saved to results/result_UDMIS012EXT_N36_W1.0_R0.2.orig_1700088517.527098.json
# finished 2023-11-15 22:49:35.539233
# process instances/UDMIS085EXT_N40_W1.0_R0.2.orig.json 2023-11-15 22:49:35.539745
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (40, 2), factor: 4.348336584291281e-06
# num_qubits: 40
# simulator simulator turned off
# run qpu 2023-11-15 22:49:35.547731
# saved to results/result_UDMIS085EXT_N40_W1.0_R0.2.orig_1700088575.539771.json
# finished 2023-11-15 22:50:33.443948
# process instances/UDMIS059EXT_N70_W1.0_R0.1.orig.json 2023-11-15 22:50:33.445791
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (70, 2), factor: 5.665086395027374e-06
# num_qubits: 70
# simulator simulator turned off
# run qpu 2023-11-15 22:50:33.450828
# saved to results/result_UDMIS059EXT_N70_W1.0_R0.1.orig_1700088633.445829.json
# finished 2023-11-15 22:51:31.098774
# process instances/UDMIS064EXT_N90_W1.0_R0.1.orig.json 2023-11-15 22:51:31.100855
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (90, 2), factor: 5.665086395027374e-06
# num_qubits: 90
# simulator simulator turned off
# run qpu 2023-11-15 22:51:31.106014
# saved to results/result_UDMIS064EXT_N90_W1.0_R0.1.orig_1700088691.100896.json
# finished 2023-11-15 22:52:29.027851
# process instances/UDMIS022EXT_N70_W1.0_R0.1.orig.json 2023-11-15 22:52:29.029145
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (70, 2), factor: 6.435538144751096e-06
# num_qubits: 70
# simulator simulator turned off
# run qpu 2023-11-15 22:52:29.034079
# saved to results/result_UDMIS022EXT_N70_W1.0_R0.1.orig_1700088749.029182.json
# finished 2023-11-15 22:53:28.067259
# process instances/UDMIS088EXT_N49_W1.0_R0.2.orig.json 2023-11-15 22:53:28.067522
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (49, 2), factor: 4.348336584291281e-06
# num_qubits: 49
# simulator simulator turned off
# run qpu 2023-11-15 22:53:28.069188
# saved to results/result_UDMIS088EXT_N49_W1.0_R0.2.orig_1700088808.067541.json
# finished 2023-11-15 22:54:26.790686
# process instances/UDMIS046EXT_N36_W1.0_R0.2.orig.json 2023-11-15 22:54:26.790912
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (36, 2), factor: 5.665086395027374e-06
# num_qubits: 36
# simulator simulator turned off
# run qpu 2023-11-15 22:54:26.795144
# saved to results/result_UDMIS046EXT_N36_W1.0_R0.2.orig_1700088866.790927.json
# finished 2023-11-15 22:55:24.315391
# process instances/UDMIS099EXT_N80_W1.0_R0.2.orig.json 2023-11-15 22:55:24.315620
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (80, 2), factor: 4.348336584291281e-06
# num_qubits: 80
# simulator simulator turned off
# run qpu 2023-11-15 22:55:24.317719
# saved to results/result_UDMIS099EXT_N80_W1.0_R0.2.orig_1700088924.315634.json
# finished 2023-11-15 22:56:22.486035
# process instances/UDMIS051EXT_N40_W1.0_R0.2.orig.json 2023-11-15 22:56:22.486348
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (40, 2), factor: 5.665086395027374e-06
# num_qubits: 40
# simulator simulator turned off
# run qpu 2023-11-15 22:56:22.489234
# saved to results/result_UDMIS051EXT_N40_W1.0_R0.2.orig_1700088982.486367.json
# finished 2023-11-15 22:57:19.703089
# process instances/UDMIS031EXT_N100_W1.0_R0.1.orig.json 2023-11-15 22:57:19.703378
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (100, 2), factor: 6.435538144751096e-06
# num_qubits: 100
# simulator simulator turned off
# run qpu 2023-11-15 22:57:19.706392
# saved to results/result_UDMIS031EXT_N100_W1.0_R0.1.orig_1700089039.7034.json
# finished 2023-11-15 22:58:17.358478
# process instances/UDMIS017EXT_N49_W1.0_R0.2.orig.json 2023-11-15 22:58:17.358755
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (49, 2), factor: 6.435538144751096e-06
# num_qubits: 49
# simulator simulator turned off
# run qpu 2023-11-15 22:58:17.360734
# saved to results/result_UDMIS017EXT_N49_W1.0_R0.2.orig_1700089097.358771.json
# finished 2023-11-15 22:59:15.000193
# process instances/UDMIS045EXT_N30_W1.0_R0.2.orig.json 2023-11-15 22:59:15.000521
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (30, 2), factor: 5.665086395027374e-06
# num_qubits: 30
# simulator simulator turned off
# run qpu 2023-11-15 22:59:15.003779
# saved to results/result_UDMIS045EXT_N30_W1.0_R0.2.orig_1700089155.000545.json
# finished 2023-11-15 23:00:12.349576
# process instances/UDMIS025EXT_N80_W1.0_R0.1.orig.json 2023-11-15 23:00:12.349853
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (80, 2), factor: 6.435538144751096e-06
# num_qubits: 80
# simulator simulator turned off
# run qpu 2023-11-15 23:00:12.352690
# saved to results/result_UDMIS025EXT_N80_W1.0_R0.1.orig_1700089212.349872.json
# finished 2023-11-15 23:01:09.501130
# process instances/UDMIS006EXT_N25_W1.0_R0.2.orig.json 2023-11-15 23:01:09.509090
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (25, 2), factor: 6.435538144751096e-06
# num_qubits: 25
# simulator simulator turned off
# run qpu 2023-11-15 23:01:09.517923
# saved to results/result_UDMIS006EXT_N25_W1.0_R0.2.orig_1700089269.50915.json
# finished 2023-11-15 23:02:05.771261
# process instances/UDMIS100EXT_N90_W1.0_R0.2.orig.json 2023-11-15 23:02:05.771478
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (90, 2), factor: 4.348336584291281e-06
# num_qubits: 90
# simulator simulator turned off
# run qpu 2023-11-15 23:02:05.774202
# saved to results/result_UDMIS100EXT_N90_W1.0_R0.2.orig_1700089325.771494.json
# finished 2023-11-15 23:03:03.327010
# process instances/UDMIS003EXT_N15_W1.0_R0.2.orig.json 2023-11-15 23:03:03.327363
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (15, 2), factor: 6.435538144751096e-06
# num_qubits: 15
# simulator simulator turned off
# run qpu 2023-11-15 23:03:03.329488
# saved to results/result_UDMIS003EXT_N15_W1.0_R0.2.orig_1700089383.327389.json
# finished 2023-11-15 23:04:00.735546
# process instances/UDMIS087EXT_N40_W1.0_R0.2.orig.json 2023-11-15 23:04:00.735995
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (40, 2), factor: 4.348336584291281e-06
# num_qubits: 40
# simulator simulator turned off
# run qpu 2023-11-15 23:04:00.738263
# saved to results/result_UDMIS087EXT_N40_W1.0_R0.2.orig_1700089440.73601.json
# finished 2023-11-15 23:04:58.817078
# process instances/UDMIS097EXT_N80_W1.0_R0.2.orig.json 2023-11-15 23:04:58.817290
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (80, 2), factor: 4.348336584291281e-06
# num_qubits: 80
# simulator simulator turned off
# run qpu 2023-11-15 23:04:58.819422
# saved to results/result_UDMIS097EXT_N80_W1.0_R0.2.orig_1700089498.817306.json
# finished 2023-11-15 23:05:58.448873
# process instances/UDMIS011EXT_N36_W1.0_R0.2.orig.json 2023-11-15 23:05:58.449146
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (36, 2), factor: 6.435538144751096e-06
# num_qubits: 36
# simulator simulator turned off
# run qpu 2023-11-15 23:05:58.450839
# saved to results/result_UDMIS011EXT_N36_W1.0_R0.2.orig_1700089558.449161.json
# finished 2023-11-15 23:08:37.262900
# process instances/UDMIS015EXT_N40_W1.0_R0.2.orig.json 2023-11-15 23:08:37.263119
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (40, 2), factor: 6.435538144751096e-06
# num_qubits: 40
# simulator simulator turned off
# run qpu 2023-11-15 23:08:37.264801
# saved to results/result_UDMIS015EXT_N40_W1.0_R0.2.orig_1700089717.263135.json
# finished 2023-11-15 23:09:35.346434
# process instances/UDMIS093EXT_N60_W1.0_R0.2.orig.json 2023-11-15 23:09:35.346639
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (60, 2), factor: 4.348336584291281e-06
# num_qubits: 60
# simulator simulator turned off
# run qpu 2023-11-15 23:09:35.348439
# saved to results/result_UDMIS093EXT_N60_W1.0_R0.2.orig_1700089775.346654.json
# finished 2023-11-15 23:10:32.199028
# process instances/UDMIS005EXT_N25_W1.0_R0.2.orig.json 2023-11-15 23:10:32.199278
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (25, 2), factor: 6.435538144751096e-06
# num_qubits: 25
# simulator simulator turned off
# run qpu 2023-11-15 23:10:32.200588
# saved to results/result_UDMIS005EXT_N25_W1.0_R0.2.orig_1700089832.199296.json
# finished 2023-11-15 23:11:30.133405
# process instances/UDMIS040EXT_N25_W1.0_R0.2.orig.json 2023-11-15 23:11:30.133607
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (25, 2), factor: 5.665086395027374e-06
# num_qubits: 25
# simulator simulator turned off
# run qpu 2023-11-15 23:11:30.134802
# saved to results/result_UDMIS040EXT_N25_W1.0_R0.2.orig_1700089890.133624.json
# finished 2023-11-15 23:12:26.681164
# process instances/UDMIS057EXT_N60_W1.0_R0.2.orig.json 2023-11-15 23:12:26.681366
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (60, 2), factor: 5.665086395027374e-06
# num_qubits: 60
# simulator simulator turned off
# run qpu 2023-11-15 23:12:26.683361
# saved to results/result_UDMIS057EXT_N60_W1.0_R0.2.orig_1700089946.681391.json
# finished 2023-11-15 23:13:24.079418
# process instances/UDMIS108EXT_N120_W1.0_R0.2.orig.json 2023-11-15 23:13:24.079969
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (120, 2), factor: 4.348336584291281e-06
# num_qubits: 120
# simulator simulator turned off
# run qpu 2023-11-15 23:13:24.084042
# saved to results/result_UDMIS108EXT_N120_W1.0_R0.2.orig_1700090004.080001.json
# finished 2023-11-15 23:14:21.419285
# process instances/UDMIS010EXT_N36_W1.0_R0.2.orig.json 2023-11-15 23:14:21.419590
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (36, 2), factor: 6.435538144751096e-06
# num_qubits: 36
# simulator simulator turned off
# run qpu 2023-11-15 23:14:21.421012
# saved to results/result_UDMIS010EXT_N36_W1.0_R0.2.orig_1700090061.419609.json
# finished 2023-11-15 23:15:18.659579
# process instances/UDMIS041EXT_N25_W1.0_R0.2.orig.json 2023-11-15 23:15:18.660058
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (25, 2), factor: 5.665086395027374e-06
# num_qubits: 25
# simulator simulator turned off
# run qpu 2023-11-15 23:15:18.661703
# saved to results/result_UDMIS041EXT_N25_W1.0_R0.2.orig_1700090118.660085.json
# finished 2023-11-15 23:16:15.059816
# process instances/UDMIS103EXT_N100_W1.0_R0.2.orig.json 2023-11-15 23:16:15.060013
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (100, 2), factor: 4.348336584291281e-06
# num_qubits: 100
# simulator simulator turned off
# run qpu 2023-11-15 23:16:15.062536
# saved to results/result_UDMIS103EXT_N100_W1.0_R0.2.orig_1700090175.06003.json
# finished 2023-11-15 23:17:12.287077
# process instances/UDMIS067EXT_N100_W1.0_R0.1.orig.json 2023-11-15 23:17:12.287364
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (100, 2), factor: 5.665086395027374e-06
# num_qubits: 100
# simulator simulator turned off
# run qpu 2023-11-15 23:17:12.290166
# saved to results/result_UDMIS067EXT_N100_W1.0_R0.1.orig_1700090232.287383.json
# finished 2023-11-15 23:18:10.546752
# process instances/UDMIS052EXT_N49_W1.0_R0.2.orig.json 2023-11-15 23:18:10.547296
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (49, 2), factor: 5.665086395027374e-06
# num_qubits: 49
# simulator simulator turned off
# run qpu 2023-11-15 23:18:10.549809
# saved to results/result_UDMIS052EXT_N49_W1.0_R0.2.orig_1700090290.547329.json
# finished 2023-11-15 23:19:08.435763
# process instances/UDMIS102EXT_N90_W1.0_R0.2.orig.json 2023-11-15 23:19:08.436147
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (90, 2), factor: 4.348336584291281e-06
# num_qubits: 90
# simulator simulator turned off
# run qpu 2023-11-15 23:19:08.439197
# saved to results/result_UDMIS102EXT_N90_W1.0_R0.2.orig_1700090348.436176.json
# finished 2023-11-15 23:20:05.596217
# process instances/UDMIS068EXT_N100_W1.0_R0.1.orig.json 2023-11-15 23:20:05.597555
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (100, 2), factor: 5.665086395027374e-06
# num_qubits: 100
# simulator simulator turned off
# run qpu 2023-11-15 23:20:05.600934
# saved to results/result_UDMIS068EXT_N100_W1.0_R0.1.orig_1700090405.59759.json
# finished 2023-11-15 23:21:02.956108
# process instances/UDMIS035EXT_N120_W1.0_R0.1.orig.json 2023-11-15 23:21:02.957484
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (120, 2), factor: 6.435538144751096e-06
# num_qubits: 120
# simulator simulator turned off
# run qpu 2023-11-15 23:21:02.961725
# saved to results/result_UDMIS035EXT_N120_W1.0_R0.1.orig_1700090462.957528.json
# finished 2023-11-15 23:22:02.339658
# process instances/UDMIS107EXT_N120_W1.0_R0.2.orig.json 2023-11-15 23:22:02.341215
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (120, 2), factor: 4.348336584291281e-06
# num_qubits: 120
# simulator simulator turned off
# run qpu 2023-11-15 23:22:02.350025
# saved to results/result_UDMIS107EXT_N120_W1.0_R0.2.orig_1700090522.34125.json
# finished 2023-11-15 23:23:00.226051
# process instances/UDMIS034EXT_N120_W1.0_R0.1.orig.json 2023-11-15 23:23:00.226445
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (120, 2), factor: 6.435538144751096e-06
# num_qubits: 120
# simulator simulator turned off
# run qpu 2023-11-15 23:23:00.234639
# saved to results/result_UDMIS034EXT_N120_W1.0_R0.1.orig_1700090580.226471.json
# finished 2023-11-15 23:23:57.903112
# process instances/UDMIS020EXT_N60_W1.0_R0.1.orig.json 2023-11-15 23:23:57.903416
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (60, 2), factor: 6.435538144751096e-06
# num_qubits: 60
# simulator simulator turned off
# run qpu 2023-11-15 23:23:57.905307
# saved to results/result_UDMIS020EXT_N60_W1.0_R0.1.orig_1700090637.903434.json
# finished 2023-11-15 23:24:54.954802
# process instances/UDMIS066EXT_N90_W1.0_R0.1.orig.json 2023-11-15 23:24:54.955054
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (90, 2), factor: 5.665086395027374e-06
# num_qubits: 90
# simulator simulator turned off
# run qpu 2023-11-15 23:24:54.958675
# saved to results/result_UDMIS066EXT_N90_W1.0_R0.1.orig_1700090694.955071.json
# finished 2023-11-15 23:25:53.387615
# process instances/UDMIS007EXT_N30_W1.0_R0.2.orig.json 2023-11-15 23:25:53.387874
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (30, 2), factor: 6.435538144751096e-06
# num_qubits: 30
# simulator simulator turned off
# run qpu 2023-11-15 23:25:53.389635
# saved to results/result_UDMIS007EXT_N30_W1.0_R0.2.orig_1700090753.387891.json
# finished 2023-11-15 23:26:50.537872
# process instances/UDMIS061EXT_N80_W1.0_R0.1.orig.json 2023-11-15 23:26:50.538672
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (80, 2), factor: 5.665086395027374e-06
# num_qubits: 80
# simulator simulator turned off
# run qpu 2023-11-15 23:26:50.545329
# saved to results/result_UDMIS061EXT_N80_W1.0_R0.1.orig_1700090810.538705.json
# finished 2023-11-15 23:27:49.006565
# process instances/UDMIS092EXT_N60_W1.0_R0.2.orig.json 2023-11-15 23:27:49.006869
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (60, 2), factor: 4.348336584291281e-06
# num_qubits: 60
# simulator simulator turned off
# run qpu 2023-11-15 23:27:49.008870
# saved to results/result_UDMIS092EXT_N60_W1.0_R0.2.orig_1700090869.006887.json
# finished 2023-11-15 23:28:45.213547
# process instances/UDMIS080EXT_N30_W1.0_R0.3.orig.json 2023-11-15 23:28:45.213792
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (30, 2), factor: 4.348336584291281e-06
# num_qubits: 30
# simulator simulator turned off
# run qpu 2023-11-15 23:28:45.215449
# saved to results/result_UDMIS080EXT_N30_W1.0_R0.3.orig_1700090925.213807.json
# finished 2023-11-15 23:29:43.811242
# process instances/UDMIS044EXT_N30_W1.0_R0.2.orig.json 2023-11-15 23:29:43.811512
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (30, 2), factor: 5.665086395027374e-06
# num_qubits: 30
# simulator simulator turned off
# run qpu 2023-11-15 23:29:43.813082
# saved to results/result_UDMIS044EXT_N30_W1.0_R0.2.orig_1700090983.811541.json
# finished 2023-11-15 23:30:41.308664
# process instances/UDMIS096EXT_N70_W1.0_R0.2.orig.json 2023-11-15 23:30:41.308863
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (70, 2), factor: 4.348336584291281e-06
# num_qubits: 70
# simulator simulator turned off
# run qpu 2023-11-15 23:30:41.310492
# saved to results/result_UDMIS096EXT_N70_W1.0_R0.2.orig_1700091041.308878.json
# finished 2023-11-15 23:31:37.710503
# process instances/UDMIS050EXT_N40_W1.0_R0.2.orig.json 2023-11-15 23:31:37.710814
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (40, 2), factor: 5.665086395027374e-06
# num_qubits: 40
# simulator simulator turned off
# run qpu 2023-11-15 23:31:37.712731
# saved to results/result_UDMIS050EXT_N40_W1.0_R0.2.orig_1700091097.710834.json
# finished 2023-11-15 23:32:36.395470
# process instances/UDMIS048EXT_N36_W1.0_R0.2.orig.json 2023-11-15 23:32:36.397803
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (36, 2), factor: 5.665086395027374e-06
# num_qubits: 36
# simulator simulator turned off
# run qpu 2023-11-15 23:32:36.399301
# saved to results/result_UDMIS048EXT_N36_W1.0_R0.2.orig_1700091156.397846.json
# finished 2023-11-15 23:33:34.817040
# process instances/UDMIS075EXT_N15_W1.0_R0.4.orig.json 2023-11-15 23:33:34.820690
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (15, 2), factor: 4.348336584291281e-06
# num_qubits: 15
# simulator simulator turned off
# run qpu 2023-11-15 23:33:34.822071
# saved to results/result_UDMIS075EXT_N15_W1.0_R0.4.orig_1700091214.820742.json
# finished 2023-11-15 23:34:32.475094
# process instances/UDMIS001EXT_N15_W1.0_R0.2.orig.json 2023-11-15 23:34:32.475276
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (15, 2), factor: 6.435538144751096e-06
# num_qubits: 15
# simulator simulator turned off
# run qpu 2023-11-15 23:34:32.476577
# saved to results/result_UDMIS001EXT_N15_W1.0_R0.2.orig_1700091272.47529.json
# finished 2023-11-15 23:35:29.618903
# process instances/UDMIS070EXT_N120_W1.0_R0.1.orig.json 2023-11-15 23:35:29.619146
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (120, 2), factor: 5.665086395027374e-06
# num_qubits: 120
# simulator simulator turned off
# run qpu 2023-11-15 23:35:29.622338
# saved to results/result_UDMIS070EXT_N120_W1.0_R0.1.orig_1700091329.619164.json
# finished 2023-11-15 23:36:28.180237
# process instances/UDMIS083EXT_N36_W1.0_R0.3.orig.json 2023-11-15 23:36:28.181057
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (36, 2), factor: 4.348336584291281e-06
# num_qubits: 36
# simulator simulator turned off
# run qpu 2023-11-15 23:36:28.183621
# saved to results/result_UDMIS083EXT_N36_W1.0_R0.3.orig_1700091388.181101.json
# finished 2023-11-15 23:37:25.279407
# process instances/UDMIS071EXT_N120_W1.0_R0.1.orig.json 2023-11-15 23:37:25.279920
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (120, 2), factor: 5.665086395027374e-06
# num_qubits: 120
# simulator simulator turned off
# run qpu 2023-11-15 23:37:25.282971
# saved to results/result_UDMIS071EXT_N120_W1.0_R0.1.orig_1700091445.279954.json
# finished 2023-11-15 23:38:22.975254
# process instances/UDMIS076EXT_N25_W1.0_R0.3.orig.json 2023-11-15 23:38:22.975642
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (25, 2), factor: 4.348336584291281e-06
# num_qubits: 25
# simulator simulator turned off
# run qpu 2023-11-15 23:38:22.977263
# saved to results/result_UDMIS076EXT_N25_W1.0_R0.3.orig_1700091502.975669.json
# finished 2023-11-15 23:39:20.722224
# process instances/UDMIS060EXT_N70_W1.0_R0.1.orig.json 2023-11-15 23:39:20.724547
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (70, 2), factor: 5.665086395027374e-06
# num_qubits: 70
# simulator simulator turned off
# run qpu 2023-11-15 23:39:20.726733
# saved to results/result_UDMIS060EXT_N70_W1.0_R0.1.orig_1700091560.724581.json
# finished 2023-11-15 23:40:21.258475
# process instances/UDMIS053EXT_N49_W1.0_R0.2.orig.json 2023-11-15 23:40:21.258853
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (49, 2), factor: 5.665086395027374e-06
# num_qubits: 49
# simulator simulator turned off
# run qpu 2023-11-15 23:40:21.260848
# saved to results/result_UDMIS053EXT_N49_W1.0_R0.2.orig_1700091621.258881.json
# finished 2023-11-15 23:41:18.123973
# process instances/UDMIS029EXT_N90_W1.0_R0.1.orig.json 2023-11-15 23:41:18.124251
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (90, 2), factor: 6.435538144751096e-06
# num_qubits: 90
# simulator simulator turned off
# run qpu 2023-11-15 23:41:18.126680
# saved to results/result_UDMIS029EXT_N90_W1.0_R0.1.orig_1700091678.124293.json
# finished 2023-11-15 23:42:15.275950
# process instances/UDMIS062EXT_N80_W1.0_R0.1.orig.json 2023-11-15 23:42:15.277250
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (80, 2), factor: 5.665086395027374e-06
# num_qubits: 80
# simulator simulator turned off
# run qpu 2023-11-15 23:42:15.282194
# saved to results/result_UDMIS062EXT_N80_W1.0_R0.1.orig_1700091735.277287.json
# finished 2023-11-15 23:43:12.431471
# process instances/UDMIS095EXT_N70_W1.0_R0.2.orig.json 2023-11-15 23:43:12.432128
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (70, 2), factor: 4.348336584291281e-06
# num_qubits: 70
# simulator simulator turned off
# run qpu 2023-11-15 23:43:12.434669
# saved to results/result_UDMIS095EXT_N70_W1.0_R0.2.orig_1700091792.432151.json
# finished 2023-11-15 23:44:09.495450
# process instances/UDMIS090EXT_N49_W1.0_R0.2.orig.json 2023-11-15 23:44:09.495839
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (49, 2), factor: 4.348336584291281e-06
# num_qubits: 49
# simulator simulator turned off
# run qpu 2023-11-15 23:44:09.503062
# saved to results/result_UDMIS090EXT_N49_W1.0_R0.2.orig_1700091849.495866.json
# finished 2023-11-15 23:45:06.372628
# process instances/UDMIS033EXT_N100_W1.0_R0.1.orig.json 2023-11-15 23:45:06.372936
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (100, 2), factor: 6.435538144751096e-06
# num_qubits: 100
# simulator simulator turned off
# run qpu 2023-11-15 23:45:06.376588
# saved to results/result_UDMIS033EXT_N100_W1.0_R0.1.orig_1700091906.372956.json
# finished 2023-11-15 23:46:04.162564
# process instances/UDMIS078EXT_N25_W1.0_R0.3.orig.json 2023-11-15 23:46:04.162868
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (25, 2), factor: 4.348336584291281e-06
# num_qubits: 25
# simulator simulator turned off
# run qpu 2023-11-15 23:46:04.164349
# saved to results/result_UDMIS078EXT_N25_W1.0_R0.3.orig_1700091964.162886.json
# finished 2023-11-15 23:47:02.619825
# process instances/UDMIS016EXT_N49_W1.0_R0.2.orig.json 2023-11-15 23:47:02.620661
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (49, 2), factor: 6.435538144751096e-06
# num_qubits: 49
# simulator simulator turned off
# run qpu 2023-11-15 23:47:02.624770
# saved to results/result_UDMIS016EXT_N49_W1.0_R0.2.orig_1700092022.62098.json
# finished 2023-11-15 23:48:01.103716
# process instances/UDMIS014EXT_N40_W1.0_R0.2.orig.json 2023-11-15 23:48:01.103959
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (40, 2), factor: 6.435538144751096e-06
# num_qubits: 40
# simulator simulator turned off
# run qpu 2023-11-15 23:48:01.105488
# saved to results/result_UDMIS014EXT_N40_W1.0_R0.2.orig_1700092081.103976.json
# finished 2023-11-15 23:48:57.873987
# process instances/UDMIS056EXT_N60_W1.0_R0.2.orig.json 2023-11-15 23:48:57.874437
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (60, 2), factor: 5.665086395027374e-06
# num_qubits: 60
# simulator simulator turned off
# run qpu 2023-11-15 23:48:57.876254
# saved to results/result_UDMIS056EXT_N60_W1.0_R0.2.orig_1700092137.874454.json
# finished 2023-11-15 23:49:55.242921
# process instances/UDMIS072EXT_N120_W1.0_R0.1.orig.json 2023-11-15 23:49:55.243305
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (120, 2), factor: 5.665086395027374e-06
# num_qubits: 120
# simulator simulator turned off
# run qpu 2023-11-15 23:49:55.247174
# saved to results/result_UDMIS072EXT_N120_W1.0_R0.1.orig_1700092195.243327.json
# finished 2023-11-15 23:50:51.995550
# process instances/UDMIS074EXT_N15_W1.0_R0.4.orig.json 2023-11-15 23:50:51.996007
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (15, 2), factor: 4.348336584291281e-06
# num_qubits: 15
# simulator simulator turned off
# run qpu 2023-11-15 23:50:51.997606
# saved to results/result_UDMIS074EXT_N15_W1.0_R0.4.orig_1700092251.996032.json
# finished 2023-11-15 23:51:49.689623
# process instances/UDMIS055EXT_N60_W1.0_R0.2.orig.json 2023-11-15 23:51:49.689862
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (60, 2), factor: 5.665086395027374e-06
# num_qubits: 60
# simulator simulator turned off
# run qpu 2023-11-15 23:51:49.691636
# saved to results/result_UDMIS055EXT_N60_W1.0_R0.2.orig_1700092309.689881.json
# finished 2023-11-15 23:52:46.108480
# process instances/UDMIS004EXT_N25_W1.0_R0.2.orig.json 2023-11-15 23:52:46.108936
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (25, 2), factor: 6.435538144751096e-06
# num_qubits: 25
# simulator simulator turned off
# run qpu 2023-11-15 23:52:46.112176
# saved to results/result_UDMIS004EXT_N25_W1.0_R0.2.orig_1700092366.108957.json
# finished 2023-11-15 23:53:43.909063
# process instances/UDMIS054EXT_N49_W1.0_R0.2.orig.json 2023-11-15 23:53:43.909362
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (49, 2), factor: 5.665086395027374e-06
# num_qubits: 49
# simulator simulator turned off
# run qpu 2023-11-15 23:53:43.916223
# saved to results/result_UDMIS054EXT_N49_W1.0_R0.2.orig_1700092423.909389.json
# finished 2023-11-15 23:54:42.112701
# process instances/UDMIS079EXT_N30_W1.0_R0.3.orig.json 2023-11-15 23:54:42.112995
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (30, 2), factor: 4.348336584291281e-06
# num_qubits: 30
# simulator simulator turned off
# run qpu 2023-11-15 23:54:42.115493
# saved to results/result_UDMIS079EXT_N30_W1.0_R0.3.orig_1700092482.113027.json
# finished 2023-11-15 23:55:40.708054
# process instances/UDMIS042EXT_N25_W1.0_R0.2.orig.json 2023-11-15 23:55:40.708374
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (25, 2), factor: 5.665086395027374e-06
# num_qubits: 25
# simulator simulator turned off
# run qpu 2023-11-15 23:55:40.709791
# saved to results/result_UDMIS042EXT_N25_W1.0_R0.2.orig_1700092540.708399.json
# finished 2023-11-15 23:56:38.245997
# process instances/UDMIS091EXT_N60_W1.0_R0.2.orig.json 2023-11-15 23:56:38.246201
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (60, 2), factor: 4.348336584291281e-06
# num_qubits: 60
# simulator simulator turned off
# run qpu 2023-11-15 23:56:38.248391
# saved to results/result_UDMIS091EXT_N60_W1.0_R0.2.orig_1700092598.246217.json
# finished 2023-11-15 23:57:34.970567
# process instances/UDMIS065EXT_N90_W1.0_R0.1.orig.json 2023-11-15 23:57:34.971011
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (90, 2), factor: 5.665086395027374e-06
# num_qubits: 90
# simulator simulator turned off
# run qpu 2023-11-15 23:57:34.975680
# saved to results/result_UDMIS065EXT_N90_W1.0_R0.1.orig_1700092654.971045.json
# finished 2023-11-15 23:58:31.839943
# process instances/UDMIS104EXT_N100_W1.0_R0.2.orig.json 2023-11-15 23:58:31.841480
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (100, 2), factor: 4.348336584291281e-06
# num_qubits: 100
# simulator simulator turned off
# run qpu 2023-11-15 23:58:31.848021
# saved to results/result_UDMIS104EXT_N100_W1.0_R0.2.orig_1700092711.841516.json
# finished 2023-11-15 23:59:29.754603
# process instances/UDMIS098EXT_N80_W1.0_R0.2.orig.json 2023-11-15 23:59:29.755242
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (80, 2), factor: 4.348336584291281e-06
# num_qubits: 80
# simulator simulator turned off
# run qpu 2023-11-15 23:59:29.757871
# saved to results/result_UDMIS098EXT_N80_W1.0_R0.2.orig_1700092769.755274.json
# finished 2023-11-16 00:00:27.177696
# process instances/UDMIS018EXT_N49_W1.0_R0.2.orig.json 2023-11-16 00:00:27.177995
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (49, 2), factor: 6.435538144751096e-06
# num_qubits: 49
# simulator simulator turned off
# run qpu 2023-11-16 00:00:27.179594
# saved to results/result_UDMIS018EXT_N49_W1.0_R0.2.orig_1700092827.178012.json
# finished 2023-11-16 00:01:24.553766
# process instances/UDMIS032EXT_N100_W1.0_R0.1.orig.json 2023-11-16 00:01:24.554038
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (100, 2), factor: 6.435538144751096e-06
# num_qubits: 100
# simulator simulator turned off
# run qpu 2023-11-16 00:01:24.556969
# saved to results/result_UDMIS032EXT_N100_W1.0_R0.1.orig_1700092884.554056.json
# finished 2023-11-16 00:02:23.519350
# process instances/UDMIS019EXT_N60_W1.0_R0.1.orig.json 2023-11-16 00:02:23.519654
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (60, 2), factor: 6.435538144751096e-06
# num_qubits: 60
# simulator simulator turned off
# run qpu 2023-11-16 00:02:23.521608
# saved to results/result_UDMIS019EXT_N60_W1.0_R0.1.orig_1700092943.519672.json
# finished 2023-11-16 00:03:21.536144
# process instances/UDMIS023EXT_N70_W1.0_R0.1.orig.json 2023-11-16 00:03:21.536557
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (70, 2), factor: 6.435538144751096e-06
# num_qubits: 70
# simulator simulator turned off
# run qpu 2023-11-16 00:03:21.541776
# saved to results/result_UDMIS023EXT_N70_W1.0_R0.1.orig_1700093001.53659.json
# finished 2023-11-16 00:04:19.752426
# process instances/UDMIS105EXT_N100_W1.0_R0.2.orig.json 2023-11-16 00:04:19.752670
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (100, 2), factor: 4.348336584291281e-06
# num_qubits: 100
# simulator simulator turned off
# run qpu 2023-11-16 00:04:19.755150
# saved to results/result_UDMIS105EXT_N100_W1.0_R0.2.orig_1700093059.752687.json
# finished 2023-11-16 00:05:16.390675
# process instances/UDMIS077EXT_N25_W1.0_R0.3.orig.json 2023-11-16 00:05:16.390984
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (25, 2), factor: 4.348336584291281e-06
# num_qubits: 25
# simulator simulator turned off
# run qpu 2023-11-16 00:05:16.392335
# saved to results/result_UDMIS077EXT_N25_W1.0_R0.3.orig_1700093116.391002.json
# finished 2023-11-16 00:06:13.321564
# process instances/UDMIS036EXT_N120_W1.0_R0.1.orig.json 2023-11-16 00:06:13.321802
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (120, 2), factor: 6.435538144751096e-06
# num_qubits: 120
# simulator simulator turned off
# run qpu 2023-11-16 00:06:13.345632
# saved to results/result_UDMIS036EXT_N120_W1.0_R0.1.orig_1700093173.321818.json
# finished 2023-11-16 00:08:54.454502
# process instances/UDMIS037EXT_N15_W1.0_R0.3.orig.json 2023-11-16 00:08:54.454799
# Delta_final     = 20000000.0
# C6              = 5.42e-24
# blockade_radius = 8.04442268093887e-06
# data dimension: (15, 2), factor: 5.665086395027374e-06
# num_qubits: 15
# simulator simulator turned off
# run qpu 2023-11-16 00:08:54.456237
